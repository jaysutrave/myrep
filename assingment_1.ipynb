# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
# *
# &#39;hello&#39;
# -87.8
# -
# /
# +
# 6

# %% [markdown]
#  answer(1) :-
# values :- 'hello',-87.8,6
# expressions :- *,-,/,+

# %% [markdown]
# 2.What is the difference between string and variable?

# %% [markdown]
# answer(2) :-vairable can store information
# and string is data type which can be store in a vairable

# %% [markdown]
# 3.Describe three different data types.

# %% [markdown]
# answer(3) :- datatypes
# 1 :- int ---  it store the integer value i.e 1,2,3,4
# 2:- string --- it store the string value i.e 'hello','this is my first python assingment'
# 3 :- float --- it store the floating value i.e 2.5,3.6,1.2,0.7

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# answer(4) :- expression is made of operator and oprends i.e 2+4,5/2
#     where 2 is operend and + is a operator.
#     all the expression peforms an operation and give the user a specific output

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?

# %% [markdown]
# answer(5) :- in this statement spam = 10 we are assigning the value 10 to a variable i.e spam
#     expression meanse an operation perform on variable which will give a desired output
#     but
#     statement means action or a command action's like assignment,print

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %% [markdown]
# answer(6):- 23

# %% [markdown]
# 7. What should the values of the following two terms be?
# &#39;spam&#39; + &#39;spamspam&#39;
# &#39;spam&#39; * 3

# %% [markdown]
# answer(7) :- both statement will give the same output i.e 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# answer(8):- bacause 100 is a number and variable name cannot start with integer

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string
# version of a value?

# %% [markdown]
# answer(9) :- int(),float(),str()

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# &#39;I have eaten &#39; + 99 + &#39; burritos.&#39;

# %% [markdown]
# answer(10) :- it gives the error because we cannot add int + string
#     we can slove, using '99' insted of 99 because now the compiler will understand the 99 is a string i.e
#     'i have eaten'+'99'+'burritos'
